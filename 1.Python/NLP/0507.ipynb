# %%
from sklearn.feature_extraction import DictVectorizer
import pandas as pd

# %%
kor_begin = 44032
kor_end = 55203
chosung_base = 588
jungsung_base = 28
jaum_begin = 12593
jaum_end = 12622
moum_begin = 12623
moum_end = 12643

chosung_list = [ 'ㄱ', 'ㄲ', 'ㄴ', 'ㄷ', 'ㄸ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅃ', 
        'ㅅ', 'ㅆ', 'ㅇ' , 'ㅈ', 'ㅉ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']

jungsung_list = ['ㅏ', 'ㅐ', 'ㅑ', 'ㅒ', 'ㅓ', 'ㅔ', 
        'ㅕ', 'ㅖ', 'ㅗ', 'ㅘ', 'ㅙ', 'ㅚ', 
        'ㅛ', 'ㅜ', 'ㅝ', 'ㅞ', 'ㅟ', 'ㅠ', 
        'ㅡ', 'ㅢ', 'ㅣ']

jongsung_list = [
    ' ', 'ㄱ', 'ㄲ', 'ㄳ', 'ㄴ', 'ㄵ', 'ㄶ', 'ㄷ',
        'ㄹ', 'ㄺ', 'ㄻ', 'ㄼ', 'ㄽ', 'ㄾ', 'ㄿ', 'ㅀ', 
        'ㅁ', 'ㅂ', 'ㅄ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅊ', 
        'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']

jaum_list = ['ㄱ', 'ㄲ', 'ㄳ', 'ㄴ', 'ㄵ', 'ㄶ', 'ㄷ', 'ㄸ', 'ㄹ', 
              'ㄺ', 'ㄻ', 'ㄼ', 'ㄽ', 'ㄾ', 'ㄿ', 'ㅀ', 'ㅁ', 'ㅂ', 
              'ㅃ', 'ㅄ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅉ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']

moum_list = ['ㅏ', 'ㅐ', 'ㅑ', 'ㅒ', 'ㅓ', 'ㅔ', 'ㅕ', 'ㅖ', 'ㅗ', 'ㅘ', 
              'ㅙ', 'ㅚ', 'ㅛ', 'ㅜ', 'ㅝ', 'ㅞ', 'ㅟ', 'ㅠ', 'ㅡ', 'ㅢ', 'ㅣ']

def compose(chosung, jungsung, jongsung):
    char = chr(
        kor_begin +
        chosung_base * chosung_list.index(chosung) +
        jungsung_base * jungsung_list.index(jungsung) +
        jongsung_list.index(jongsung)
    )
    return char

def decompose(c):
    if not character_is_korean(c):
        return None
    i = ord(c)
    if (jaum_begin <= i <= jaum_end):
        return (c, ' ', ' ')
    if (moum_begin <= i <= moum_end):
        return (' ', c, ' ')

    # decomposition rule
    i -= kor_begin
    cho  = i // chosung_base
    jung = ( i - cho * chosung_base ) // jungsung_base 
    jong = ( i - cho * chosung_base - jung * jungsung_base )    
    return (chosung_list[cho], jungsung_list[jung], jongsung_list[jong])

def character_is_korean(c):
    i = ord(c)
    return ((kor_begin <= i <= kor_end) or
            (jaum_begin <= i <= jaum_end) or
            (moum_begin <= i <= moum_end))

# %%
def levenshtein(s1, s2, debug=False):
    if len(s1) < len(s2):
        return levenshtein(s2, s1, debug)

    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1
            deletions = current_row[j] + 1
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))

        if debug:
            print(current_row[1:])

        previous_row = current_row

    return previous_row[-1]

# %%
def jamo_levenshtein(s1, s2):
    if len(s1) < len(s2):
        return jamo_levenshtein(s2, s1)

    if len(s2) == 0:
        return len(s1)
    
    def get_jamo_cost(c1, c2):
        if c1 == c2:
            return 0
        jamo1 = decompose(c1)
        jamo2 = decompose(c2)
        if jamo1 is None or jamo2 is None:
            return 1
        return levenshtein(decompose(c1), decompose(c2)) / 3

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1 # j+1 instead of j since previous_row and current_row are one character longer
            deletions = current_row[j] + 1       # than s2
            substitutions = previous_row[j] + get_jamo_cost(c1, c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
    
    return previous_row[-1]

# %%
jamo_levenshtein('가나다-','나당라')
# Out:
# 2.333333333333333

# %%
pwd
# Out:
# 'C:\\Users\\admin\\Downloads\\ken\\kcc'

# %%
hotel = pd.read_csv('./hotel_csv.csv', encoding='cp949', engine='python')
hotel.columns = ['item', 'size', 'unit']
hotel_ = hotel.dropna(subset=['item', 'unit'], how='any')
wonju = pd.read_csv('./wonju.csv', encoding='cp949',engine='python')
wonju.columns = ['item', 'size', 'unit', 'amount']
wonju_ = wonju.dropna(subset=['item', 'unit'], how='any')
wonju_ = wonju_.reset_index(drop=True)
hotel_ = hotel_.reset_index(drop=True)

def custom_lev(col1, col2):
    w_item = wonju_[col1].tolist()
    h_item = hotel_[col2].tolist()
    all_dict = {}
    for i in w_item:
        all_dict[i]= [5000000012351518 , i, 0 ]
        for j in h_item :
            
            distance = jamo_levenshtein(str(i), str(j))
            accuracy = jamo_levenshtein(str(i), str(j))
            if distance < all_dict[i][0]:
                all_dict[i] = [distance, j, accuracy]
    return all_dict

# %%
arrr = custom_lev('item', 'item')

only_item = wonju_.copy()

only_item['items_dist'] = wonju_['item'].map(lambda x : arrr[x][0])
only_item['items_min_name'] = wonju_['item'].map(lambda x : arrr[x][1])
only_item['lev_dist_accuracy'] = wonju_['item'].map(lambda x : round(arrr[x][2],2))

# %%
only_item.sort_values(by='items_dist').head(50)
# Out:
#                 item                                size   unit     amount  \
# 116        창문틀 주위 충전                             모르타르 충전      M     56.000
# 35            콘크리트벽돌       콘크리트벽돌, 190*57*90mm, 강원, C종2급      매  17418.000
# 79             오픈트랜치                 양면, L-25*25*3t 아연도금      M     20.000
# 37             벽돌 운반                              인력, 2층     천매      8.130
# 38         0.5B 벽돌쌓기                             3.6m 이하     M2     24.000
# 39         1.0B 벽돌쌓기                             3.6m 이하     M2    100.000
# 163              시멘트                                 건재상      포    948.000
# 162               모래                             모래, 도착도     M3     77.000
# 142   선홈통-스텐레스파이프-설치                        ∮127.0*1.2mm      M     43.000
# 90          콘크리트면 정리                                 NaN     M2    167.000
# 87   방수 모르타르 바름 / 바닥                20mm 이하, 벽돌, 콘크리트 바탕     M2    213.000
# 85           모르타르 바름                            바닥, 33mm     M2     95.000
# 57           스틸점검구뚜껑                  무늬강판, 600*600*3.2t      개      1.000
# 117        창문틀 주위 충전                            발포우레탄 충전      M    460.000
# 84           모르타르 바름                            바닥, 47mm     M2    248.000
# 60        스테인리스재료분리대                    바닥, W30*H20*1.5t      M     23.000
# 63     베이스비드(홈내기) 설치                          AL, H=10mm      M    182.000
# 64       철재커텐박스(ㄱ자형)             120*120*1.2t, STL(도장 유)      M      6.000
# 65       철재커텐박스(ㄱ자형)             120*330*1.2t, STL(도장 유)      M     13.000
# 83           모르타르 바름                            외벽, 18mm     M2    107.000
# 82           모르타르 바름                   내벽, 11mm, 3.6m 이하     M2    998.000
# 81           모르타르 바름                  내천정, 15mm, 3.6m 이하     M2     14.000
# 26       유로폼 설치 및 해체                        보통, 수직고 7m까지     M2   3225.000
# 25       유로폼 설치 및 해체                        간단, 수직고 7m까지     M2    515.000
# 36             벽돌 운반                              인력, 1층     천매      8.457
# 76         알루미늄 시트패널             평판 t=3 불소수지, 하지틀포함, 시공도     M2    406.000
# 7      강관 조립말비계(이동식)                          높이 2m, 3개월      대     10.000
# 129          비닐타일 깔기             비닐타일, 3*450*450mm, 데코타일     M2    248.000
# 138      루프드레인(L형)설치                              D100mm     개소      5.000
# 139      루프드레인(L형)설치                              D125mm     개소      6.000
# 141   선홈통-스텐레스파이프-설치                        ∮101.6*1.2mm      M      3.000
# 130  악세스후로아(전도성타일마감)              우드코아판넬 600각 t=3.0, 시공도     M2    121.000
# 16         방습필름 - 바닥             폴리에틸렌필름, 두께, 0.05mm, 2겹     M2    487.000
# 9     시스템동바리 설치 및 해체                  3개월, 10m이하 , 자재비포함  10공M3     75.000
# 125  바탕만들기+걸레받이용 페인트                  붓칠, 2회, 콘크리트·모르타르면     M2     25.000
# 10     건축물 보양 - 콘크리트                                  살수     M2    955.000
# 124           유리주위코킹                            5*5, 실리콘      M   1453.000
# 2             평판재하시험                                 NaN     회당      2.000
# 118        수밀코킹(실리콘)                      삼각, 10mm, 창호주위      M   1030.000
# 11           건축물현장정리                             철근콘크리트조     M2    955.000
# 45            타일코너비드       스테인리스, 라운드(STS4, 10*10*0.5mm)      M     50.000
# 42         시멘트 액체 방수                                 수직부     M2     95.000
# 61        AL몰딩설치(W형)                   15*15*15*15*1.0mm      M    347.000
# 4             수평 규준틀                                   귀     개소      9.000
# 41         시멘트 액체 방수                                  바닥     M2     63.000
# 32               철강설                     철강설, 고철, 작업설부산물     kg  -2858.000
# 172             철근시험                                인장강도      회      4.000
# 170              잔골재                            비중 및 흡수율      회      1.000
# 88    방수 모르타르 바름 / 벽  18mm, 벽돌, 콘크리트 바탕, 지하층~지상3층(10.8m)     M2     73.000
# 62        AL몰딩설치(ㄷ형)                      15*30*15*1.0mm      M    237.000
#
#      items_dist   items_min_name  lev_dist_accuracy
# 116    0.000000        창문틀 주위 충전               0.00
# 35     0.000000           콘크리트벽돌               0.00
# 79     0.000000            오픈트랜치               0.00
# 37     0.000000            벽돌 운반               0.00
# 38     0.000000        0.5B 벽돌쌓기               0.00
# 39     0.000000        1.0B 벽돌쌓기               0.00
# 163    0.000000              시멘트               0.00
# 162    0.000000               모래               0.00
# 142    0.000000   선홈통-스텐레스파이프-설치               0.00
# 90     0.000000         콘크리트면 정리               0.00
# 87     0.000000  방수 모르타르 바름 / 바닥               0.00
# 85     0.000000          모르타르 바름               0.00
# 57     0.000000          스틸점검구뚜껑               0.00
# 117    0.000000        창문틀 주위 충전               0.00
# 84     0.000000          모르타르 바름               0.00
# 60     0.000000       스테인리스재료분리대               0.00
# 63     0.000000    베이스비드(홈내기) 설치               0.00
# 64     0.000000      철재커텐박스(ㄱ자형)               0.00
# 65     0.000000      철재커텐박스(ㄱ자형)               0.00
# 83     0.000000          모르타르 바름               0.00
# 82     0.000000          모르타르 바름               0.00
# 81     0.000000          모르타르 바름               0.00
# 26     0.000000      유로폼 설치 및 해체               0.00
# 25     0.000000      유로폼 설치 및 해체               0.00
# 36     0.000000            벽돌 운반               0.00
# 76     0.000000        알루미늄 시트패널               0.00
# 7      0.000000    강관 조립말비계(이동식)               0.00
# 129    0.000000          비닐타일 깔기               0.00
# 138    0.000000      루프드레인(L형)설치               0.00
# 139    0.000000      루프드레인(L형)설치               0.00
# 141    0.000000   선홈통-스텐레스파이프-설치               0.00
# 130    0.000000  악세스후로아(전도성타일마감)               0.00
# 16     0.000000        방습필름 - 바닥               0.00
# 9      0.000000   시스템동바리 설치 및 해체               0.00
# 125    0.000000  바탕만들기+걸레받이용 페인트               0.00
# 10     0.000000    건축물 보양 - 콘크리트               0.00
# 124    0.000000           유리주위코킹               0.00
# 2      0.000000           평판재하시험               0.00
# 118    0.000000        수밀코킹(실리콘)               0.00
# 11     0.000000          건축물현장정리               0.00
# 45     1.000000          타일벽코너비드               1.00
# 42     1.000000         시멘트 액체방수               1.00
# 61     1.000000        AL몰딩설(W형)               1.00
# 4      1.000000            수평규준틀               1.00
# 41     1.000000         시멘트 액체방수               1.00
# 32     1.333333             철강채널               1.33
# 172    1.666667             철근조립               1.67
# 170    1.666667               자갈               1.67
# 88     1.666667  방수 모르타르 바름 / 바닥               1.67
# 62     2.000000        AL몰딩설(W형)               2.00

# %%
#only_item.to_excel('./only_itemname_morepheme_v1_0507.xlsx', index=False, encoding='cp949')

# %%
wonju_['item']
# Out:
# 0                  컨테이너형 가설건축물 - 창고.
# 1                 컨테이너형 가설건축물 - 사무실.
# 2                             평판재하시험
# 3                           조립식가설실험실
# 4                             수평 규준틀
# 5                            구조부 먹매김
# 6                   강관비계(쌍줄) 설치 및 해체
# 7                      강관 조립말비계(이동식)
# 8                      강관동바리 설치 및 해체
# 9                     시스템동바리 설치 및 해체
# 10                     건축물 보양 - 콘크리트
# 11                           건축물현장정리
# 12                            터파기/토사
# 13                  되메우기/토사, 두께 30cm
# 14                    토사 운반/단지외 10km
# 15            발포폴리스티렌(슬래브 위 깔기 - 바닥)
# 16                         방습필름 - 바닥
# 17                            잡석깔기지정
# 18             콘크리트 펌프차 타설(무근, 진동기無)
# 19               콘크리트 펌프차 타설(매트기초 등)
# 20     콘크리트 펌프차 타설(벽,기둥,슬래브 등) [PIT]
# 21     콘크리트 펌프차 타설(벽,기둥,슬래브 등) [01F]
# 22     콘크리트 펌프차 타설(벽,기둥,슬래브 등) [02F]
# 23     콘크리트 펌프차 타설(벽,기둥,슬래브 등) [RF1]
# 24     콘크리트 펌프차 타설(벽,기둥,슬래브 등) [PH1]
# 25                       유로폼 설치 및 해체
# 26                       유로폼 설치 및 해체
# 27       합판거푸집 설치 및 해체 - 지붕슬래브(노임할증)
# 28                 콘크리트 진동기(엔진식,인력유)
# 29      합판거푸집 설치 및 해체 - 일반슬래브(노임미할증)
#                    ...
# 165                            벽돌운반비
# 166                            시멘트운반
# 167                           콘크리트시험
# 168                           콘크리트시험
# 169                             굵은골재
# 170                              잔골재
# 171                            시멘트시험
# 172                             철근시험
# 173                          시멘트벽돌시험
# 174       2) 품질관련 문서 작성 및 관리에 관련한 비용
# 175                    3) 품질관련 교육훈련비
# 176                         4) 품질검사비
# 177                       5) 그 밖의 비용
# 178            레미콘 [물품식별번호:10063096]
# 179            레미콘 [물품식별번호:10063091]
# 180      철근콘크리트용봉강 [물품식별번호:10063865]
# 181      철근콘크리트용봉강 [물품식별번호:10063866]
# 182      철근콘크리트용봉강 [물품식별번호:10063867]
# 183      철근콘크리트용봉강 [물품식별번호:10063868]
# 184                            자연석판석
# 185                준불연로이단열재(F3-100T)
# 186                          * 조달수수료
# 187                           * 자리맞춤
# 188     알루미늄 단열프로젝트창 [식별번호:23061490]
# 189         알루미늄 방충망 [식별번호:22873089]
# 190            장애인승용(WBSS), 기계실없는 제품
# 191       20T하니클보드 [물품식별번호:22156724]
# 192         8T강화유리 [물품식별번호:22156733]
# 193                          * 조달수수료
# 194                           * 자리맞춤
# Name: item, Length: 195, dtype: object

# %% [markdown]
# # NLP 적용 0507

# %%
import codecs
from bs4 import BeautifulSoup
from konlpy.tag import Twitter
import warnings
warnings.filterwarnings('ignore')

# %%
twitter = Twitter()
word_dic = {}
lines = wonju_['item']
for line in lines :
    malist = twitter.pos(line)
    for word in malist :
        if word[1] == "Noun":
            if not (word[0] in word_dic):
                word_dic[word[0]] = 0
            word_dic[word[0]] += 1

# %%
word_dic
# Out:
# {'컨테이너': 2,
#  '가설': 3,
#  '건축물': 4,
#  '창고': 1,
#  '사무실': 1,
#  '평판': 1,
#  '시험': 6,
#  '조립': 3,
#  '실험실': 1,
#  '수평': 1,
#  '규준': 1,
#  '틀': 3,
#  '조부': 1,
#  '먹매김': 1,
#  '강관': 2,
#  '비계': 2,
#  '쌍줄': 1,
#  '설치': 24,
#  '및': 8,
#  '해체': 7,
#  '말': 1,
#  '이동식': 1,
#  '강': 1,
#  '관동': 1,
#  '바리': 1,
#  '시스템': 1,
#  '동바리': 1,
#  '보양': 1,
#  '콘크리트': 16,
#  '현장': 3,
#  '정리': 2,
#  '터': 1,
#  '파기': 1,
#  '토사': 3,
#  '두께': 1,
#  '운반': 6,
#  '단지': 1,
#  '외': 1,
#  '발포': 3,
#  '폴리스티렌': 3,
#  '슬래브': 9,
#  '위': 2,
#  '바닥': 6,
#  '방습': 2,
#  '필름': 2,
#  '잡석': 1,
#  '지정': 1,
#  '펌프': 7,
#  '차': 7,
#  '설': 9,
#  '무근': 1,
#  '진동기': 2,
#  '매트': 1,
#  '기초': 1,
#  '등': 6,
#  '벽': 8,
#  '기둥': 5,
#  '유로폼': 2,
#  '합판': 2,
#  '거푸집': 2,
#  '지붕': 4,
#  '노임': 2,
#  '할증': 2,
#  '엔진': 1,
#  '인력': 1,
#  '유': 1,
#  '일반': 1,
#  '철근': 3,
#  '보통': 2,
#  '가공': 1,
#  '철강': 1,
#  '경량': 4,
#  '방재': 2,
#  '벽돌': 7,
#  '프라이머': 3,
#  '바름': 8,
#  '시멘트': 6,
#  '액체': 2,
#  '방수': 6,
#  '우레': 2,
#  '포함': 5,
#  '타일': 4,
#  '코너': 1,
#  '비드': 2,
#  '바탕': 5,
#  '도': 2,
#  '기질': 2,
#  '압착': 3,
#  '압': 3,
#  '포슬린': 1,
#  '화강석': 7,
#  '재료': 2,
#  '분리': 2,
#  '습': 6,
#  '물': 3,
#  '갈기': 3,
#  '겁돌': 1,
#  '버너': 3,
#  '자재': 3,
#  '관': 3,
#  '별도': 3,
#  '건': 1,
#  '앵커': 1,
#  '잔': 2,
#  '스틸': 2,
#  '점검': 1,
#  '뚜껑': 1,
#  '스테인리스': 7,
#  '사다리': 1,
#  '세라믹': 1,
#  '논': 1,
#  '슬립': 1,
#  '몰딩': 2,
#  '형': 4,
#  '베이스': 1,
#  '홈': 1,
#  '내기': 1,
#  '철재': 2,
#  '커텐': 2,
#  '박스': 2,
#  '자형': 2,
#  '계단': 3,
#  '실': 4,
#  '안전': 1,
#  '난간': 3,
#  '핸드': 6,
#  '레일': 6,
#  '부형': 3,
#  '복도': 1,
#  '홀': 1,
#  '옥상': 1,
#  '테라스': 2,
#  '투시': 1,
#  '후': 2,
#  '레싱': 2,
#  '목적': 1,
#  '알루미늄': 6,
#  '시트': 3,
#  '창호': 1,
#  '겁': 1,
#  '파라': 1,
#  '펫': 1,
#  '천장': 1,
#  '철골틀': 1,
#  '패널': 1,
#  '장재': 3,
#  '합성': 1,
#  '목재': 1,
#  '데크': 1,
#  '오픈': 1,
#  '트랜': 1,
#  '치': 1,
#  '표면': 1,
#  '마무리': 1,
#  '모르타르': 7,
#  '판넬': 1,
#  '히팅': 1,
#  '와이어': 1,
#  '메시': 1,
#  '견적': 22,
#  '폴딩': 2,
#  '도어': 2,
#  '스텐레스': 3,
#  '프레임': 3,
#  '방화': 1,
#  '문': 1,
#  '세이프': 3,
#  '강화도': 3,
#  '단열': 2,
#  '부자': 3,
#  '재': 4,
#  '항목': 3,
#  '창문': 2,
#  '주위': 3,
#  '충전': 2,
#  '밀코킹': 1,
#  '실리콘': 1,
#  '강화유리': 2,
#  '투명': 4,
#  '복층': 2,
#  '유리': 5,
#  '로이': 2,
#  '삼중': 2,
#  '코킹': 1,
#  '만들기': 1,
#  '걸레받이': 1,
#  '용': 2,
#  '페인트': 3,
#  '무늬': 1,
#  '코트': 1,
#  '수성': 2,
#  '롤러': 2,
#  '칠': 2,
#  '비닐': 1,
#  '스후': 1,
#  '전도성': 1,
#  '마감': 1,
#  '카펫': 1,
#  '부착': 1,
#  '열경화성수지': 1,
#  '준불연': 1,
#  '불': 1,
#  '연천': 1,
#  '칸막이': 2,
#  '메탈': 1,
#  '스타트': 1,
#  '방음': 1,
#  '루프': 2,
#  '드': 2,
#  '레인': 2,
#  '스텐': 1,
#  '상자': 1,
#  '홈통': 1,
#  '선홈통': 2,
#  '스텐레': 2,
#  '스파': 2,
#  '이프': 2,
#  '유아': 1,
#  '거치': 1,
#  '촉': 2,
#  '판': 2,
#  '종합': 1,
#  '안내': 1,
#  '도벽': 1,
#  '실과': 1,
#  '명촉': 1,
#  '강도': 1,
#  '점자': 2,
#  '블럭': 2,
#  '양면': 1,
#  '접착': 1,
#  '패드': 2,
#  '장비': 1,
#  '상부': 1,
#  '돌출': 1,
#  '부': 1,
#  '엘리베이터': 1,
#  '후크': 1,
#  '관로': 3,
#  '오수': 1,
#  '우수': 3,
#  '각형': 1,
#  '맨홀': 1,
#  '기성품': 1,
#  '보': 1,
#  '차도': 1,
#  '경계': 1,
#  '석': 1,
#  '화강암': 1,
#  '직선': 1,
#  '소형': 1,
#  '고압': 1,
#  '블록': 1,
#  '포장': 1,
#  '쇄': 1,
#  '자갈': 1,
#  '혼합': 1,
#  '골재': 3,
#  '모래': 1,
#  '비': 4,
#  '트레일러': 1,
#  '크레인': 1,
#  '품질': 3,
#  '관련': 3,
#  '문서': 1,
#  '작성': 1,
#  '관리': 1,
#  '비용': 2,
#  '교육': 1,
#  '훈련': 1,
#  '검사': 1,
#  '그': 1,
#  '밖': 1,
#  '레미콘': 2,
#  '물품': 8,
#  '식별': 10,
#  '번호': 10,
#  '철근콘크리트': 4,
#  '용봉강': 4,
#  '자연석': 1,
#  '판석': 1,
#  '준불': 1,
#  '연로': 1,
#  '이단': 1,
#  '조달': 2,
#  '수수료': 2,
#  '자리': 2,
#  '맞춤': 2,
#  '프로젝트': 1,
#  '창': 1,
#  '방충': 1,
#  '망': 1,
#  '장애': 1,
#  '인승': 1,
#  '기계': 1,
#  '제품': 1,
#  '하니': 1,
#  '보드': 1}

# %%
keys = sorted(word_dic.items(), key=lambda x:x[1], reverse = True)
for word, count in keys[:50]:
    print('{0}({1})'.format(word, count), end="")
print()
# Out:
# 설치(24)견적(22)콘크리트(16)식별(10)번호(10)슬래브(9)설(9)및(8)벽(8)바름(8)물품(8)해체(7)펌프(7)차(7)벽돌(7)화강석(7)스테인리스(7)모르타르(7)시험(6)운반(6)바닥(6)등(6)시멘트(6)방수(6)습(6)핸드(6)레일(6)알루미늄(6)기둥(5)포함(5)바탕(5)유리(5)건축물(4)지붕(4)경량(4)타일(4)형(4)실(4)재(4)투명(4)비(4)철근콘크리트(4)용봉강(4)가설(3)조립(3)틀(3)현장(3)토사(3)발포(3)폴리스티렌(3)

# %%
from gensim.models import word2vec

twitter = Twitter()
results = []
lines = wonju_['item']
for line in lines :
    malist = twitter.pos(line, norm=True, stem=True)
    r = []
    for word in malist :
        # 어미/조사/구두점 등은 대상에서 제외
        if not word[1] in ['Josa', "Eomi", "Punctuation"]:
            r.append(word[0])
        rl = (" ".join(r)).strip()
        results.append(rl)
        #print(rl)

# %%
names = wonju_['item']
for i in names[:10]:
    print(i)
# Out:
# 컨테이너형 가설건축물 - 창고.
# 컨테이너형 가설건축물 - 사무실.
# 평판재하시험
# 조립식가설실험실
# 수평 규준틀
# 구조부 먹매김
# 강관비계(쌍줄) 설치 및 해체
# 강관 조립말비계(이동식)
# 강관동바리 설치 및 해체
# 시스템동바리 설치 및 해체

# %%
twitter.pos(names[0], norm=True, stem=True)
# Out:
# [('컨테이너', 'Noun'),
#  ('형', 'Suffix'),
#  ('가설', 'Noun'),
#  ('건축물', 'Noun'),
#  ('-', 'Punctuation'),
#  ('창고', 'Noun'),
#  ('.', 'Punctuation')]

# %%
# 파일로 출력하기
wakati_file = 'wonju.wakati'
with open(wakati_file, 'w', encoding = 'utf-8') as fp:
    fp.write('\n'.join(results))
    
# Word2Vec 모델 만들기
data = word2vec.LineSentence(wakati_file)
model = word2vec.Word2Vec(data,
                         size = 200, window=10, hs=1, min_count=2, sg=1)
model.save('wonju.model')
print('ok')
# Out:
# ok

# %%
results
# Out:
# ['컨테이너',
#  '컨테이너 형',
#  '컨테이너 형 가설',
#  '컨테이너 형 가설 건축물',
#  '컨테이너 형 가설 건축물',
#  '컨테이너 형 가설 건축물 창고',
#  '컨테이너 형 가설 건축물 창고',
#  '컨테이너',
#  '컨테이너 형',
#  '컨테이너 형 가설',
#  '컨테이너 형 가설 건축물',
#  '컨테이너 형 가설 건축물',
#  '컨테이너 형 가설 건축물 사무실',
#  '컨테이너 형 가설 건축물 사무실',
#  '평판',
#  '평판 재다',
#  '평판 재다 시험',
#  '조립',
#  '조립 식',
#  '조립 식 가설',
#  '조립 식 가설 실험실',
#  '수평',
#  '수평 규준',
#  '수평 규준 틀',
#  '구',
#  '구 조부',
#  '구 조부 먹매김',
#  '강관',
#  '강관 비계',
#  '강관 비계',
#  '강관 비계 쌍줄',
#  '강관 비계 쌍줄',
#  '강관 비계 쌍줄 설치',
#  '강관 비계 쌍줄 설치 및',
#  '강관 비계 쌍줄 설치 및 해체',
#  '강관',
#  '강관 조립',
#  '강관 조립 말',
#  '강관 조립 말 비계',
#  '강관 조립 말 비계',
#  '강관 조립 말 비계 이동식',
#  '강관 조립 말 비계 이동식',
#  '강',
#  '강 관동',
#  '강 관동 바리',
#  '강 관동 바리 설치',
#  '강 관동 바리 설치 및',
#  '강 관동 바리 설치 및 해체',
#  '시스템',
#  '시스템 동바리',
#  '시스템 동바리 설치',
#  '시스템 동바리 설치 및',
#  '시스템 동바리 설치 및 해체',
#  '건축물',
#  '건축물 보양',
#  '건축물 보양',
#  '건축물 보양 콘크리트',
#  '건축물',
#  '건축물 현장',
#  '건축물 현장 정리',
#  '터',
#  '터 파기',
#  '터 파기',
#  '터 파기 토사',
#  '되다',
#  '되다 메우다',
#  '되다 메우다',
#  '되다 메우다 토사',
#  '되다 메우다 토사',
#  '되다 메우다 토사 두께',
#  '되다 메우다 토사 두께 30',
#  '되다 메우다 토사 두께 30 cm',
#  '토사',
#  '토사 운반',
#  '토사 운반',
#  '토사 운반 단지',
#  '토사 운반 단지 외',
#  '토사 운반 단지 외 10',
#  '토사 운반 단지 외 10 km',
#  '발포',
#  '발포 폴리스티렌',
#  '발포 폴리스티렌',
#  '발포 폴리스티렌 슬래브',
#  '발포 폴리스티렌 슬래브 위',
#  '발포 폴리스티렌 슬래브 위 깔다',
#  '발포 폴리스티렌 슬래브 위 깔다',
#  '발포 폴리스티렌 슬래브 위 깔다 바닥',
#  '발포 폴리스티렌 슬래브 위 깔다 바닥',
#  '방습',
#  '방습 필름',
#  '방습 필름',
#  '방습 필름 바닥',
#  '잡석',
#  '잡석 깔다',
#  '잡석 깔다 지정',
#  '콘크리트',
#  '콘크리트 펌프',
#  '콘크리트 펌프 차',
#  '콘크리트 펌프 차 타',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설 무근',
#  '콘크리트 펌프 차 타 설 무근',
#  '콘크리트 펌프 차 타 설 무근 진동기',
#  '콘크리트 펌프 차 타 설 무근 진동기 無',
#  '콘크리트 펌프 차 타 설 무근 진동기 無',
#  '콘크리트',
#  '콘크리트 펌프',
#  '콘크리트 펌프 차',
#  '콘크리트 펌프 차 타',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설 매트',
#  '콘크리트 펌프 차 타 설 매트 기초',
#  '콘크리트 펌프 차 타 설 매트 기초 등',
#  '콘크리트 펌프 차 타 설 매트 기초 등',
#  '콘크리트',
#  '콘크리트 펌프',
#  '콘크리트 펌프 차',
#  '콘크리트 펌프 차 타',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 PIT',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 PIT',
#  '콘크리트',
#  '콘크리트 펌프',
#  '콘크리트 펌프 차',
#  '콘크리트 펌프 차 타',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 01',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 01 F',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 01 F',
#  '콘크리트',
#  '콘크리트 펌프',
#  '콘크리트 펌프 차',
#  '콘크리트 펌프 차 타',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 02',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 02 F',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 02 F',
#  '콘크리트',
#  '콘크리트 펌프',
#  '콘크리트 펌프 차',
#  '콘크리트 펌프 차 타',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 RF',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 RF 1',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 RF 1',
#  '콘크리트',
#  '콘크리트 펌프',
#  '콘크리트 펌프 차',
#  '콘크리트 펌프 차 타',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 PH',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 PH 1',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 PH 1',
#  '유로폼',
#  '유로폼 설치',
#  '유로폼 설치 및',
#  '유로폼 설치 및 해체',
#  '유로폼',
#  '유로폼 설치',
#  '유로폼 설치 및',
#  '유로폼 설치 및 해체',
#  '합판',
#  '합판 거푸집',
#  '합판 거푸집 설치',
#  '합판 거푸집 설치 및',
#  '합판 거푸집 설치 및 해체',
#  '합판 거푸집 설치 및 해체',
#  '합판 거푸집 설치 및 해체 지붕',
#  '합판 거푸집 설치 및 해체 지붕 슬래브',
#  '합판 거푸집 설치 및 해체 지붕 슬래브',
#  '합판 거푸집 설치 및 해체 지붕 슬래브 노임',
#  '합판 거푸집 설치 및 해체 지붕 슬래브 노임 할증',
#  '합판 거푸집 설치 및 해체 지붕 슬래브 노임 할증',
#  '콘크리트',
#  '콘크리트 진동기',
#  '콘크리트 진동기',
#  '콘크리트 진동기 엔진',
#  '콘크리트 진동기 엔진 식',
#  '콘크리트 진동기 엔진 식',
#  '콘크리트 진동기 엔진 식 인력',
#  '콘크리트 진동기 엔진 식 인력 유',
#  '콘크리트 진동기 엔진 식 인력 유',
#  '합판',
#  '합판 거푸집',
#  '합판 거푸집 설치',
#  '합판 거푸집 설치 및',
#  '합판 거푸집 설치 및 해체',
#  '합판 거푸집 설치 및 해체',
#  '합판 거푸집 설치 및 해체 일반',
#  '합판 거푸집 설치 및 해체 일반 슬래브',
#  '합판 거푸집 설치 및 해체 일반 슬래브',
#  '합판 거푸집 설치 및 해체 일반 슬래브 노임',
#  '합판 거푸집 설치 및 해체 일반 슬래브 노임 밉다',
#  '합판 거푸집 설치 및 해체 일반 슬래브 노임 밉다 할증',
#  '합판 거푸집 설치 및 해체 일반 슬래브 노임 밉다 할증',
#  '철근',
#  '철근',
#  '철근 현장',
#  '철근 현장',
#  '철근 현장 보통',
#  '철근 현장 보통 가공',
#  '철근',
#  '철근',
#  '철근 현장',
#  '철근 현장',
#  '철근 현장 보통',
#  '철근 현장 보통 조립',
#  '철강',
#  '철강 설',
#  '경량',
#  '경량',
#  '경량 방재',
#  '경량',
#  '경량',
#  '경량 방재',
#  '콘크리트',
#  '콘크리트 벽돌',
#  '벽돌',
#  '벽돌 운반',
#  '벽돌',
#  '벽돌 운반',
#  '0.5',
#  '0.5 B',
#  '0.5 B 벽돌',
#  '0.5 B 벽돌 쌓다',
#  '1.0',
#  '1.0 B',
#  '1.0 B 벽돌',
#  '1.0 B 벽돌 쌓다',
#  '프라이머',
#  '프라이머 바름',
#  '프라이머 바름 2회',
#  '프라이머 바름 2회',
#  '프라이머 바름 2회 방습',
#  '프라이머 바름 2회 방습 필름',
#  '프라이머 바름 2회 방습 필름 2회',
#  '시멘트',
#  '시멘트 액체',
#  '시멘트 액체 방수',
#  '시멘트',
#  '시멘트 액체',
#  '시멘트 액체 방수',
#  '우레',
#  '우레 타다',
#  '우레 타다 방수',
#  '우레 타다 방수',
#  '우레 타다 방수 프라이머',
#  '우레 타다 방수 프라이머 포함',
#  '우레',
#  '우레 타다',
#  '우레 타다 방수',
#  '우레 타다 방수',
#  '우레 타다 방수 프라이머',
#  '우레 타다 방수 프라이머 포함',
#  '타일',
#  '타일 코너',
#  '타일 코너 비드',
#  '타일',
#  '타일 뜨다',
#  '타일 뜨다 붙이다',
#  '타일 뜨다 붙이다',
#  '타일 뜨다 붙이다 바탕',
#  '타일 뜨다 붙이다 바탕 24',
#  '타일 뜨다 붙이다 바탕 24 mm',
#  '타일 뜨다 붙이다 바탕 24 mm',
#  '타일 뜨다 붙이다 바탕 24 mm 도',
#  '타일 뜨다 붙이다 바탕 24 mm 도 기질',
#  '타일 뜨다 붙이다 바탕 24 mm 도 기질',
#  '타',
#  '타 일',
#  '타 일 압착',
#  '타 일 압착 붙이다',
#  '타 일 압착 붙이다',
#  '타 일 압착 붙이다 바탕',
#  '타 일 압착 붙이다 바탕 12',
#  '타 일 압착 붙이다 바탕 12 mm',
#  '타 일 압착 붙이다 바탕 12 mm',
#  '타 일 압착 붙이다 바탕 12 mm 압',
#  '타 일 압착 붙이다 바탕 12 mm 압 6',
#  '타 일 압착 붙이다 바탕 12 mm 압 6 mm',
#  '타 일 압착 붙이다 바탕 12 mm 압 6 mm',
#  '타 일 압착 붙이다 바탕 12 mm 압 6 mm',
#  '타 일 압착 붙이다 바탕 12 mm 압 6 mm 도',
#  '타 일 압착 붙이다 바탕 12 mm 압 6 mm 도 기질',
#  '타 일 압착 붙이다 바탕 12 mm 압 6 mm 도 기질',
#  '타',
#  '타 일',
#  '타 일 압착',
#  '타 일 압착 붙이다',
#  '타 일 압착 붙이다',
#  '타 일 압착 붙이다 바탕',
#  '타 일 압착 붙이다 바탕 68',
#  '타 일 압착 붙이다 바탕 68 mm',
#  '타 일 압착 붙이다 바탕 68 mm',
#  '타 일 압착 붙이다 바탕 68 mm 압',
#  '타 일 압착 붙이다 바탕 68 mm 압 5',
#  '타 일 압착 붙이다 바탕 68 mm 압 5 mm',
#  '타 일 압착 붙이다 바탕 68 mm 압 5 mm',
#  '타 일 압착 붙이다 바탕 68 mm 압 5 mm',
#  '타 일 압착 붙이다 바탕 68 mm 압 5 mm 자다',
#  '타 일 압착 붙이다 바탕 68 mm 압 5 mm 자다',
#  '타',
#  '타 일',
#  '타 일 압착',
#  '타 일 압착 붙이다',
#  '타 일 압착 붙이다',
#  '타 일 압착 붙이다 바탕',
#  '타 일 압착 붙이다 바탕 40',
#  '타 일 압착 붙이다 바탕 40 mm',
#  '타 일 압착 붙이다 바탕 40 mm',
#  '타 일 압착 붙이다 바탕 40 mm 압',
#  '타 일 압착 붙이다 바탕 40 mm 압 5',
#  '타 일 압착 붙이다 바탕 40 mm 압 5 mm',
#  '타 일 압착 붙이다 바탕 40 mm 압 5 mm',
#  '타 일 압착 붙이다 바탕 40 mm 압 5 mm',
#  '타 일 압착 붙이다 바탕 40 mm 압 5 mm 포슬린',
#  '타 일 압착 붙이다 바탕 40 mm 압 5 mm 포슬린',
#  '화강석',
#  '화강석 재료',
#  '화강석 재료 분리',
#  '화강석 재료 분리 대',
#  '화강석 재료 분리 대',
#  '화강석 재료 분리 대 습',
#  '화강석 재료 분리 대 습 식',
#  '화강석 재료 분리 대 습 식',
#  '화강석 재료 분리 대 습 식 물',
#  '화강석 재료 분리 대 습 식 물 갈기',
#  '화강석 재료 분리 대 습 식 물 갈기',
#  '화강석',
#  '화강석 붙이다',
#  '화강석 붙이다',
#  '화강석 붙이다 습',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식 물',
#  '화강석 붙이다 습 식 물 갈기',
#  '화강석 붙이다 습 식 물 갈기',
#  '화강석',
#  '화강석 두',
#  '화강석 두 겁돌',
#  '화강석 두 겁돌',
#  '화강석 두 겁돌 습',
#  '화강석 두 겁돌 습 식',
#  '화강석 두 겁돌 습 식',
#  '화강석 두 겁돌 습 식 버너',
#  '화강석 두 겁돌 습 식 버너',
#  '화강석',
#  '화강석 붙이다',
#  '화강석 붙이다',
#  '화강석 붙이다 습',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식 물',
#  '화강석 붙이다 습 식 물 갈기',
#  '화강석 붙이다 습 식 물 갈기',
#  '화강석',
#  '화강석 붙이다',
#  '화강석 붙이다',
#  '화강석 붙이다 습',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식 버너',
#  '화강석 붙이다 습 식 버너',
#  '화강석 붙이다 습 식 버너',
#  '화강석 붙이다 습 식 버너 주',
#  '화강석 붙이다 습 식 버너 주 자재',
#  '화강석 붙이다 습 식 버너 주 자재 관',
#  '화강석 붙이다 습 식 버너 주 자재 관 급',
#  '화강석 붙이다 습 식 버너 주 자재 관 급 별도',
#  '화강석 붙이다 습 식 버너 주 자재 관 급 별도',
#  '화강석',
#  '화강석 붙이다',
#  '화강석 붙이다',
#  '화강석 붙이다 건',
#  '화강석 붙이다 건 식',
#  '화강석 붙이다 건 식',
#  '화강석 붙이다 건 식 앵커',
#  '화강석 붙이다 건 식 앵커',
#  '화강석 붙이다 건 식 앵커 버너',
#  '화강석 붙이다 건 식 앵커 버너',
#  '화강석 붙이다 건 식 앵커 버너',
#  '화강석 붙이다 건 식 앵커 버너 주',
#  '화강석 붙이다 건 식 앵커 버너 주 자재',
#  '화강석 붙이다 건 식 앵커 버너 주 자재 관',
#  '화강석 붙이다 건 식 앵커 버너 주 자재 관 급',
#  '화강석 붙이다 건 식 앵커 버너 주 자재 관 급 별도',
#  '화강석 붙이다 건 식 앵커 버너 주 자재 관 급 별도',
#  '화강석',
#  '화강석 붙이다',
#  '화강석 붙이다',
#  '화강석 붙이다 습',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식 잔',
#  '화강석 붙이다 습 식 잔 다듬다',
#  '화강석 붙이다 습 식 잔 다듬다',
#  '스틸',
#  '스틸 점검',
#  '스틸 점검 구',
#  '스틸 점검 구 뚜껑',
#  '스테인리스',
#  '스테인리스 사다리',
#  '세라믹',
#  '세라믹 논',
#  '세라믹 논 슬립',
#  '세라믹 논 슬립 설치',
#  '스테인리스',
#  '스테인리스 재료',
#  '스테인리스 재료 분리',
#  '스테인리스 재료 분리 대',
#  'AL',
#  'AL 몰딩',
#  'AL 몰딩 설치',
#  'AL 몰딩 설치',
#  'AL 몰딩 설치 W',
#  'AL 몰딩 설치 W 형',
#  'AL 몰딩 설치 W 형',
#  'AL',
#  'AL 몰딩',
#  'AL 몰딩 설치',
#  'AL 몰딩 설치',
#  'AL 몰딩 설치 ㄷ',
#  'AL 몰딩 설치 ㄷ 형',
#  'AL 몰딩 설치 ㄷ 형',
#  '베이스',
#  '베이스 비드',
#  '베이스 비드',
#  '베이스 비드 홈',
#  '베이스 비드 홈 내기',
#  '베이스 비드 홈 내기',
#  '베이스 비드 홈 내기 설치',
#  '철재',
#  '철재 커텐',
#  '철재 커텐 박스',
#  '철재 커텐 박스',
#  '철재 커텐 박스 ㄱ',
#  '철재 커텐 박스 ㄱ 자형',
#  '철재 커텐 박스 ㄱ 자형',
#  '철재',
#  '철재 커텐',
#  '철재 커텐 박스',
#  '철재 커텐 박스',
#  '철재 커텐 박스 ㄱ',
#  '철재 커텐 박스 ㄱ 자형',
#  '철재 커텐 박스 ㄱ 자형',
#  '계단',
#  '계단 실',
#  '계단 실 안전',
#  '계단 실 안전 난간',
#  '스테인리스',
#  '스테인리스 핸드',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일 계단',
#  '스테인리스 핸드 레일 계단 실',
#  '스테인리스 핸드 레일 계단 실',
#  '스테인리스',
#  '스테인리스 핸드',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일 벽',
#  '스테인리스 핸드 레일 벽 부형',
#  '스테인리스 핸드 레일 벽 부형',
#  '스테인리스 핸드 레일 벽 부형 계단',
#  '스테인리스 핸드 레일 벽 부형 계단 실',
#  '스테인리스 핸드 레일 벽 부형 계단 실',
#  '스테인리스',
#  '스테인리스 핸드',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일 벽',
#  '스테인리스 핸드 레일 벽 부형',
#  '스테인리스 핸드 레일 벽 부형',
#  '스테인리스 핸드 레일 벽 부형 복도',
#  '스테인리스 핸드 레일 벽 부형 복도 홀',
#  '스테인리스 핸드 레일 벽 부형 복도 홀',
#  '스테인리스',
#  '스테인리스 핸드',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일 옥상',
#  '스테인리스 핸드 레일 옥상 난간',
#  '스테인리스 핸드 레일 옥상 난간',
#  '스틸',
#  '스틸 핸드',
#  '스틸 핸드 레일',
#  '스틸 핸드 레일',
#  '스틸 핸드 레일 테라스',
#  '스틸 핸드 레일 테라스 난간',
#  '스틸 핸드 레일 테라스 난간',
#  '스틸 핸드 레일 테라스 난간 투시',
#  '스틸 핸드 레일 테라스 난간 투시 형',
#  '스틸 핸드 레일 테라스 난간 투시 형',
#  '후',
#  '후 레싱',
#  '후 레싱 스테인리스',
#  '후 레싱 스테인리스',
#  '후 레싱 스테인리스 다',
#  '후 레싱 스테인리스 다 목적',
#  '후 레싱 스테인리스 다 목적 실',
#  '후 레싱 스테인리스 다 목적 실 지붕',
#  '후 레싱 스테인리스 다 목적 실 지붕',
#  '후',
#  '후 레싱',
#  '후 레싱 알루미늄',
#  '후 레싱 알루미늄 시트',
#  '후 레싱 알루미늄 시트',
#  '후 레싱 알루미늄 시트 창호',
#  '후 레싱 알루미늄 시트 창호',
#  '두',
#  '두 겁',
#  '두 겁 대',
#  '두 겁 대 알루미늄',
#  '두 겁 대 알루미늄 시트',
#  '두 겁 대 알루미늄 시트',
#  '두 겁 대 알루미늄 시트 파라',
#  '두 겁 대 알루미늄 시트 파라 펫',
#  '두 겁 대 알루미늄 시트 파라 펫',
#  '경량',
#  '경량 천장',
#  '경량 천장 철골틀',
#  '알루미늄',
#  '알루미늄 시트',
#  '알루미늄 시트 패널',
#  '알루미늄',
#  '알루미늄 천',
#  '알루미늄 천 장재',
#  '합성',
#  '합성 목재',
#  '합성 목재 데크',
#  '합성 목재 데크 깔다',
#  '합성 목재 데크 깔다',
#  '합성 목재 데크 깔다 테라스',
#  '합성 목재 데크 깔다 테라스',
#  '오픈',
#  '오픈 트랜',
#  '오픈 트랜 치',
#  '표면',
#  '표면 마무리',
#  '모르타르',
#  '모르타르 바름',
#  '모르타르',
#  '모르타르 바름',
#  '모르타르',
#  '모르타르 바름',
#  '모르타르',
#  '모르타르 바름',
#  '모르타르',
#  '모르타르 바름',
#  '판넬',
#  '판넬 히팅',
#  '판넬 히팅',
#  '판넬 히팅 160',
#  '판넬 히팅 160 mm',
#  '판넬 히팅 160 mm',
#  '방수',
#  '방수 모르타르',
#  '방수 모르타르 바름',
#  '방수 모르타르 바름',
#  '방수 모르타르 바름 바닥',
#  '방수',
#  '방수 모르타르',
#  '방수 모르타르 바름',
#  '방수 모르타르 바름',
#  '방수 모르타르 바름 벽',
#  '와이어',
#  '와이어 메시',
#  '와이어 메시 바닥',
#  '와이어 메시 바닥 깔다',
#  '콘크리트',
#  '콘크리트',
#  '콘크리트 정리',
#  '',
#  '견적',
#  '견적',
#  '견적 AD',
#  '견적 AD',
#  '견적 AD 1',
#  '견적 AD 1',
#  '견적 AD 1 단',
#  '견적 AD 1 단 열',
#  '견적 AD 1 단 열 폴딩',
#  '견적 AD 1 단 열 폴딩 도어',
#  '견적 AD 1 단 열 폴딩 도어',
#  '',
#  '견적',
#  '견적',
#  '견적 AD',
#  '견적 AD',
#  '견적 AD 2',
#  '견적 AD 2',
#  '견적 AD 2 단',
#  '견적 AD 2 단 열',
#  '견적 AD 2 단 열 폴딩',
#  '견적 AD 2 단 열 폴딩 도어',
#  '견적 AD 2 단 열 폴딩 도어',
#  '',
#  '견적',
#  '견적',
#  '견적 SSD',
#  '견적 SSD',
#  '견적 SSD 1',
#  '견적 SSD 1',
#  '견적 SSD 1 단',
#  '견적 SSD 1 단 열',
#  '견적 SSD 1 단 열 스텐레스',
#  '견적 SSD 1 단 열 스텐레스 프레임',
#  '견적 SSD 1 단 열 스텐레스 프레임',
#  '',
#  '견적',
#  '견적',
#  '견적 SSD',
#  '견적 SSD',
#  '견적 SSD 2',
#  '견적 SSD 2',
#  '견적 SSD 2 단',
#  '견적 SSD 2 단 열',
#  '견적 SSD 2 단 열 스텐레스',
#  '견적 SSD 2 단 열 스텐레스 프레임',
#  '견적 SSD 2 단 열 스텐레스 프레임',
#  '',
#  '견적',
#  '견적',
#  '견적 SSD',
#  '견적 SSD',
#  '견적 SSD 3',
#  '견적 SSD 3',
#  '견적 SSD 3 단',
#  '견적 SSD 3 단 열',
#  '견적 SSD 3 단 열 스텐레스',
#  '견적 SSD 3 단 열 스텐레스 프레임',
#  '견적 SSD 3 단 열 스텐레스 프레임',
#  '',
#  '견적',
#  '견적',
#  '견적 SSD',
#  '견적 SSD',
#  '견적 SSD 4',
#  '',
#  '견적',
#  '견적',
#  '견적 SSD',
#  '견적 SSD',
#  '견적 SSD 5',
#  '',
#  '견적',
#  '견적',
#  '견적 SSD',
#  '견적 SSD',
#  '견적 SSD 6',
#  '',
#  '견적',
#  '견적',
#  '견적 SD',
#  '견적 SD',
#  '견적 SD 1',
#  '견적 SD 1',
#  '견적 SD 1 단',
#  '견적 SD 1 단 열',
#  '견적 SD 1 단 열 방화',
#  '견적 SD 1 단 열 방화 문',
#  '견적 SD 1 단 열 방화 문',
#  '',
#  '견적',
#  '견적',
#  '견적 SD',
#  '견적 SD',
#  '견적 SD 2',
#  '',
#  '견적',
#  '견적',
#  '견적 SD',
#  '견적 SD',
#  '견적 SD 3',
#  '',
#  '견적',
#  '견적',
#  '견적 SD',
#  '견적 SD',
#  '견적 SD 4',
#  '',
#  '견적',
#  '견적',
#  '견적 SD',
#  '견적 SD',
#  '견적 SD 5',
#  '',
#  '견적',
#  '견적',
#  '견적 PD',
#  '견적 PD',
#  '견적 PD 1',
#  '',
#  '견적',
#  '견적',
#  '견적 PD',
#  '견적 PD',
#  '견적 PD 2',
#  '',
#  '견적',
#  '견적',
#  '견적 PD',
#  '견적 PD',
#  '견적 PD 3',
#  '',
#  '견적',
#  '견적',
#  '견적 세이프',
#  '견적 세이프 강화도',
#  '견적 세이프 강화도 어',
#  '견적 세이프 강화도 어',
#  '견적 세이프 강화도 어 단열',
#  '견적 세이프 강화도 어 단열',
#  '',
#  '견적',
#  '견적',
#  '견적 세이프',
#  '견적 세이프 강화도',
#  '견적 세이프 강화도 어',
#  '견적 세이프 강화도 어',
#  '견적 세이프 강화도 어 단열',
#  '견적 세이프 강화도 어 단열',
#  '',
#  '견적',
#  '견적',
#  '견적 세이프',
#  '견적 세이프 강화도',
#  '견적 세이프 강화도 어',
#  'SSD',
#  'SSD 부자',
#  'SSD 부자 재',
#  'SSD 부자 재',
#  'SSD 부자 재 견적',
#  'SSD 부자 재 견적 밉다',
#  'SSD 부자 재 견적 밉다 포함',
#  'SSD 부자 재 견적 밉다 포함 항목',
#  'SSD 부자 재 견적 밉다 포함 항목',
#  'SD',
#  'SD 부자',
#  'SD 부자 재',
#  'SD 부자 재',
#  'SD 부자 재 견적',
#  'SD 부자 재 견적 밉다',
#  'SD 부자 재 견적 밉다 포함',
#  'SD 부자 재 견적 밉다 포함 항목',
#  'SD 부자 재 견적 밉다 포함 항목',
#  'PD',
#  'PD 부자',
#  'PD 부자 재',
#  'PD 부자 재',
#  'PD 부자 재 견적',
#  'PD 부자 재 견적 밉다',
#  'PD 부자 재 견적 밉다 포함',
#  'PD 부자 재 견적 밉다 포함 항목',
#  'PD 부자 재 견적 밉다 포함 항목',
#  'PW',
#  'PW',
#  'PW 01',
#  'PW 01',
#  'PW 01 250',
#  'PW 01 250 mm',
#  'PW 01 250 mm',
#  'PW',
#  'PW',
#  'PW 02',
#  'PW 02',
#  'PW 02 250',
#  'PW 02 250 mm',
#  'PW 02 250 mm',
#  'PW',
#  'PW',
#  'PW 03',
#  'PW 03',
#  'PW 03 250',
#  'PW 03 250 mm',
#  'PW 03 250 mm',
#  '창문',
#  '창문 틀',
#  '창문 틀 주위',
#  '창문 틀 주위 충전',
#  '창문',
#  '창문 틀',
#  '창문 틀 주위',
#  '창문 틀 주위 충전',
#  '수',
#  '수 밀코킹',
#  '수 밀코킹',
#  '수 밀코킹 실리콘',
#  '수 밀코킹 실리콘',
#  '강화유리',
#  '강화유리',
#  '강화유리 투명',
#  '강화유리 투명',
#  '강화유리 투명 5',
#  '강화유리 투명 5 mm',
#  '투명',
#  '투명 복층',
#  '투명 복층 유리',
#  '투명 복층 유리',
#  '투명 복층 유리 24',
#  '투명 복층 유리 24 mm',
#  '투명 복층 유리 24 mm',
#  '투명 복층 유리 24 mm 6',
#  '투명 복층 유리 24 mm 6 CL',
#  '투명 복층 유리 24 mm 6 CL',
#  '투명 복층 유리 24 mm 6 CL 12',
#  '투명 복층 유리 24 mm 6 CL 12 R',
#  '투명 복층 유리 24 mm 6 CL 12 R',
#  '투명 복층 유리 24 mm 6 CL 12 R 6',
#  '투명 복층 유리 24 mm 6 CL 12 R 6 LE',
#  '투명 복층 유리 24 mm 6 CL 12 R 6 LE',
#  '로이',
#  '로이 복층',
#  '로이 복층 유리',
#  '로이 복층 유리',
#  '로이 복층 유리 28',
#  '로이 복층 유리 28 mm',
#  '로이 복층 유리 28 mm',
#  '로이 복층 유리 28 mm 6',
#  '로이 복층 유리 28 mm 6 LE',
#  '로이 복층 유리 28 mm 6 LE',
#  '로이 복층 유리 28 mm 6 LE 16',
#  '로이 복층 유리 28 mm 6 LE 16 AR',
#  '로이 복층 유리 28 mm 6 LE 16 AR',
#  '로이 복층 유리 28 mm 6 LE 16 AR 6',
#  '로이 복층 유리 28 mm 6 LE 16 AR 6 LE',
#  '로이 복층 유리 28 mm 6 LE 16 AR 6 LE',
#  '투명',
#  '투명 삼중',
#  '투명 삼중 유리',
#  '투명 삼중 유리',
#  '투명 삼중 유리 39',
#  '투명 삼중 유리 39 mm',
#  '투명 삼중 유리 39 mm',
#  '투명 삼중 유리 39 mm 5',
#  '투명 삼중 유리 39 mm 5 LE',
#  '투명 삼중 유리 39 mm 5 LE',
#  '투명 삼중 유리 39 mm 5 LE 12',
#  '투명 삼중 유리 39 mm 5 LE 12 AR',
#  '투명 삼중 유리 39 mm 5 LE 12 AR',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0 12',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0 12 AR',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0 12 AR',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0 12 AR 5',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0 12 AR 5 LE',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0 12 AR 5 LE',
#  '투명',
#  '투명 삼중',
#  '투명 삼중 유리',
#  '투명 삼중 유리',
#  '투명 삼중 유리 42',
#  '투명 삼중 유리 42 mm',
#  '투명 삼중 유리 42 mm',
#  '투명 삼중 유리 42 mm 6',
#  '투명 삼중 유리 42 mm 6 LE',
#  '투명 삼중 유리 42 mm 6 LE',
#  '투명 삼중 유리 42 mm 6 LE 12',
#  '투명 삼중 유리 42 mm 6 LE 12 AR',
#  '투명 삼중 유리 42 mm 6 LE 12 AR',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL 12',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL 12 AR',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL 12 AR',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL 12 AR 6',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL 12 AR 6 LE',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL 12 AR 6 LE',
#  '유리',
#  '유리 주위',
#  '유리 주위 코킹',
#  '바탕',
#  '바탕 만들기',
#  '바탕 만들기',
#  '바탕 만들기 걸레받이',
#  '바탕 만들기 걸레받이 용',
#  '바탕 만들기 걸레받이 용 페인트',
#  '무늬',
#  '무늬 코트',
#  '수성',
#  '수성 페인트',
#  '수성 페인트',
#  '수성 페인트 롤러',
#  '수성 페인트 롤러 칠',
#  '수성 페인트 롤러 칠',
#  '수성',
#  '수성 페인트',
#  '수성 페인트',
#  '수성 페인트 롤러',
#  '수성 페인트 롤러 칠',
#  '수성 페인트 롤러 칠',
#  '비닐',
#  '비닐 타일',
#  '비닐 타일 깔다',
#  '악세다',
#  '악세다 스후',
#  '악세다 스후',
#  '악세다 스후',
#  '악세다 스후',
#  '악세다 스후 전도성',
#  '악세다 스후 전도성 타',
#  '악세다 스후 전도성 타 일',
#  '악세다 스후 전도성 타 일 마감',
#  '악세다 스후 전도성 타 일 마감',
#  '타일',
#  '타일 카펫',
#  '타일 카펫 깔다',
#  '발포',
#  '발포 폴리스티렌',
#  '발포 폴리스티렌',
#  '발포 폴리스티렌 슬래브',
#  '발포 폴리스티렌 슬래브 위',
#  '발포 폴리스티렌 슬래브 위 깔다',
#  '발포 폴리스티렌 슬래브 위 깔다',
#  '발포 폴리스티렌 슬래브 위 깔다 바닥',
#  '발포 폴리스티렌 슬래브 위 깔다 바닥',
#  '발포',
#  '발포 폴리스티렌',
#  '발포 폴리스티렌',
#  '발포 폴리스티렌 콘크리트',
#  '발포 폴리스티렌 콘크리트 타',
#  '발포 폴리스티렌 콘크리트 타 설',
#  '발포 폴리스티렌 콘크리트 타 설 부착',
#  '발포 폴리스티렌 콘크리트 타 설 부착',
#  '발포 폴리스티렌 콘크리트 타 설 부착 바닥',
#  '발포 폴리스티렌 콘크리트 타 설 부착 바닥',
#  '열경화성수지',
#  '열경화성수지 천',
#  '열경화성수지 천 장재',
#  '로이',
#  '로이',
#  '로이 Low',
#  '로이 Low',
#  '로이 Low E',
#  '로이 Low E',
#  '로이 Low E 단',
#  '로이 Low E 단 열',
#  '로이 Low E 단 열 재',
#  '로이 Low E 단 열 재 설치',
#  '로이 Low E 단 열 재 설치',
#  '로이 Low E 단 열 재 설치 100',
#  '로이 Low E 단 열 재 설치 100 mm',
#  '로이 Low E 단 열 재 설치 100 mm',
#  '로이 Low E 단 열 재 설치 100 mm 준불연',
#  '로이 Low E 단 열 재 설치 100 mm 준불연',
#  '로이 Low E 단 열 재 설치 100 mm 준불연',
#  '로이 Low E 단 열 재 설치 100 mm 준불연 주',
#  '로이 Low E 단 열 재 설치 100 mm 준불연 주 자재',
#  '로이 Low E 단 열 재 설치 100 mm 준불연 주 자재 관',
#  ...]

# %%
from gensim.models import word2vec
model = word2vec.Word2Vec.load('wonju.model')

# %%
results
# Out:
# ['컨테이너',
#  '컨테이너 형',
#  '컨테이너 형 가설',
#  '컨테이너 형 가설 건축물',
#  '컨테이너 형 가설 건축물',
#  '컨테이너 형 가설 건축물 창고',
#  '컨테이너 형 가설 건축물 창고',
#  '컨테이너',
#  '컨테이너 형',
#  '컨테이너 형 가설',
#  '컨테이너 형 가설 건축물',
#  '컨테이너 형 가설 건축물',
#  '컨테이너 형 가설 건축물 사무실',
#  '컨테이너 형 가설 건축물 사무실',
#  '평판',
#  '평판 재다',
#  '평판 재다 시험',
#  '조립',
#  '조립 식',
#  '조립 식 가설',
#  '조립 식 가설 실험실',
#  '수평',
#  '수평 규준',
#  '수평 규준 틀',
#  '구',
#  '구 조부',
#  '구 조부 먹매김',
#  '강관',
#  '강관 비계',
#  '강관 비계',
#  '강관 비계 쌍줄',
#  '강관 비계 쌍줄',
#  '강관 비계 쌍줄 설치',
#  '강관 비계 쌍줄 설치 및',
#  '강관 비계 쌍줄 설치 및 해체',
#  '강관',
#  '강관 조립',
#  '강관 조립 말',
#  '강관 조립 말 비계',
#  '강관 조립 말 비계',
#  '강관 조립 말 비계 이동식',
#  '강관 조립 말 비계 이동식',
#  '강',
#  '강 관동',
#  '강 관동 바리',
#  '강 관동 바리 설치',
#  '강 관동 바리 설치 및',
#  '강 관동 바리 설치 및 해체',
#  '시스템',
#  '시스템 동바리',
#  '시스템 동바리 설치',
#  '시스템 동바리 설치 및',
#  '시스템 동바리 설치 및 해체',
#  '건축물',
#  '건축물 보양',
#  '건축물 보양',
#  '건축물 보양 콘크리트',
#  '건축물',
#  '건축물 현장',
#  '건축물 현장 정리',
#  '터',
#  '터 파기',
#  '터 파기',
#  '터 파기 토사',
#  '되다',
#  '되다 메우다',
#  '되다 메우다',
#  '되다 메우다 토사',
#  '되다 메우다 토사',
#  '되다 메우다 토사 두께',
#  '되다 메우다 토사 두께 30',
#  '되다 메우다 토사 두께 30 cm',
#  '토사',
#  '토사 운반',
#  '토사 운반',
#  '토사 운반 단지',
#  '토사 운반 단지 외',
#  '토사 운반 단지 외 10',
#  '토사 운반 단지 외 10 km',
#  '발포',
#  '발포 폴리스티렌',
#  '발포 폴리스티렌',
#  '발포 폴리스티렌 슬래브',
#  '발포 폴리스티렌 슬래브 위',
#  '발포 폴리스티렌 슬래브 위 깔다',
#  '발포 폴리스티렌 슬래브 위 깔다',
#  '발포 폴리스티렌 슬래브 위 깔다 바닥',
#  '발포 폴리스티렌 슬래브 위 깔다 바닥',
#  '방습',
#  '방습 필름',
#  '방습 필름',
#  '방습 필름 바닥',
#  '잡석',
#  '잡석 깔다',
#  '잡석 깔다 지정',
#  '콘크리트',
#  '콘크리트 펌프',
#  '콘크리트 펌프 차',
#  '콘크리트 펌프 차 타',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설 무근',
#  '콘크리트 펌프 차 타 설 무근',
#  '콘크리트 펌프 차 타 설 무근 진동기',
#  '콘크리트 펌프 차 타 설 무근 진동기 無',
#  '콘크리트 펌프 차 타 설 무근 진동기 無',
#  '콘크리트',
#  '콘크리트 펌프',
#  '콘크리트 펌프 차',
#  '콘크리트 펌프 차 타',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설 매트',
#  '콘크리트 펌프 차 타 설 매트 기초',
#  '콘크리트 펌프 차 타 설 매트 기초 등',
#  '콘크리트 펌프 차 타 설 매트 기초 등',
#  '콘크리트',
#  '콘크리트 펌프',
#  '콘크리트 펌프 차',
#  '콘크리트 펌프 차 타',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 PIT',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 PIT',
#  '콘크리트',
#  '콘크리트 펌프',
#  '콘크리트 펌프 차',
#  '콘크리트 펌프 차 타',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 01',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 01 F',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 01 F',
#  '콘크리트',
#  '콘크리트 펌프',
#  '콘크리트 펌프 차',
#  '콘크리트 펌프 차 타',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 02',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 02 F',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 02 F',
#  '콘크리트',
#  '콘크리트 펌프',
#  '콘크리트 펌프 차',
#  '콘크리트 펌프 차 타',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 RF',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 RF 1',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 RF 1',
#  '콘크리트',
#  '콘크리트 펌프',
#  '콘크리트 펌프 차',
#  '콘크리트 펌프 차 타',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 PH',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 PH 1',
#  '콘크리트 펌프 차 타 설 벽 기둥 슬래브 등 PH 1',
#  '유로폼',
#  '유로폼 설치',
#  '유로폼 설치 및',
#  '유로폼 설치 및 해체',
#  '유로폼',
#  '유로폼 설치',
#  '유로폼 설치 및',
#  '유로폼 설치 및 해체',
#  '합판',
#  '합판 거푸집',
#  '합판 거푸집 설치',
#  '합판 거푸집 설치 및',
#  '합판 거푸집 설치 및 해체',
#  '합판 거푸집 설치 및 해체',
#  '합판 거푸집 설치 및 해체 지붕',
#  '합판 거푸집 설치 및 해체 지붕 슬래브',
#  '합판 거푸집 설치 및 해체 지붕 슬래브',
#  '합판 거푸집 설치 및 해체 지붕 슬래브 노임',
#  '합판 거푸집 설치 및 해체 지붕 슬래브 노임 할증',
#  '합판 거푸집 설치 및 해체 지붕 슬래브 노임 할증',
#  '콘크리트',
#  '콘크리트 진동기',
#  '콘크리트 진동기',
#  '콘크리트 진동기 엔진',
#  '콘크리트 진동기 엔진 식',
#  '콘크리트 진동기 엔진 식',
#  '콘크리트 진동기 엔진 식 인력',
#  '콘크리트 진동기 엔진 식 인력 유',
#  '콘크리트 진동기 엔진 식 인력 유',
#  '합판',
#  '합판 거푸집',
#  '합판 거푸집 설치',
#  '합판 거푸집 설치 및',
#  '합판 거푸집 설치 및 해체',
#  '합판 거푸집 설치 및 해체',
#  '합판 거푸집 설치 및 해체 일반',
#  '합판 거푸집 설치 및 해체 일반 슬래브',
#  '합판 거푸집 설치 및 해체 일반 슬래브',
#  '합판 거푸집 설치 및 해체 일반 슬래브 노임',
#  '합판 거푸집 설치 및 해체 일반 슬래브 노임 밉다',
#  '합판 거푸집 설치 및 해체 일반 슬래브 노임 밉다 할증',
#  '합판 거푸집 설치 및 해체 일반 슬래브 노임 밉다 할증',
#  '철근',
#  '철근',
#  '철근 현장',
#  '철근 현장',
#  '철근 현장 보통',
#  '철근 현장 보통 가공',
#  '철근',
#  '철근',
#  '철근 현장',
#  '철근 현장',
#  '철근 현장 보통',
#  '철근 현장 보통 조립',
#  '철강',
#  '철강 설',
#  '경량',
#  '경량',
#  '경량 방재',
#  '경량',
#  '경량',
#  '경량 방재',
#  '콘크리트',
#  '콘크리트 벽돌',
#  '벽돌',
#  '벽돌 운반',
#  '벽돌',
#  '벽돌 운반',
#  '0.5',
#  '0.5 B',
#  '0.5 B 벽돌',
#  '0.5 B 벽돌 쌓다',
#  '1.0',
#  '1.0 B',
#  '1.0 B 벽돌',
#  '1.0 B 벽돌 쌓다',
#  '프라이머',
#  '프라이머 바름',
#  '프라이머 바름 2회',
#  '프라이머 바름 2회',
#  '프라이머 바름 2회 방습',
#  '프라이머 바름 2회 방습 필름',
#  '프라이머 바름 2회 방습 필름 2회',
#  '시멘트',
#  '시멘트 액체',
#  '시멘트 액체 방수',
#  '시멘트',
#  '시멘트 액체',
#  '시멘트 액체 방수',
#  '우레',
#  '우레 타다',
#  '우레 타다 방수',
#  '우레 타다 방수',
#  '우레 타다 방수 프라이머',
#  '우레 타다 방수 프라이머 포함',
#  '우레',
#  '우레 타다',
#  '우레 타다 방수',
#  '우레 타다 방수',
#  '우레 타다 방수 프라이머',
#  '우레 타다 방수 프라이머 포함',
#  '타일',
#  '타일 코너',
#  '타일 코너 비드',
#  '타일',
#  '타일 뜨다',
#  '타일 뜨다 붙이다',
#  '타일 뜨다 붙이다',
#  '타일 뜨다 붙이다 바탕',
#  '타일 뜨다 붙이다 바탕 24',
#  '타일 뜨다 붙이다 바탕 24 mm',
#  '타일 뜨다 붙이다 바탕 24 mm',
#  '타일 뜨다 붙이다 바탕 24 mm 도',
#  '타일 뜨다 붙이다 바탕 24 mm 도 기질',
#  '타일 뜨다 붙이다 바탕 24 mm 도 기질',
#  '타',
#  '타 일',
#  '타 일 압착',
#  '타 일 압착 붙이다',
#  '타 일 압착 붙이다',
#  '타 일 압착 붙이다 바탕',
#  '타 일 압착 붙이다 바탕 12',
#  '타 일 압착 붙이다 바탕 12 mm',
#  '타 일 압착 붙이다 바탕 12 mm',
#  '타 일 압착 붙이다 바탕 12 mm 압',
#  '타 일 압착 붙이다 바탕 12 mm 압 6',
#  '타 일 압착 붙이다 바탕 12 mm 압 6 mm',
#  '타 일 압착 붙이다 바탕 12 mm 압 6 mm',
#  '타 일 압착 붙이다 바탕 12 mm 압 6 mm',
#  '타 일 압착 붙이다 바탕 12 mm 압 6 mm 도',
#  '타 일 압착 붙이다 바탕 12 mm 압 6 mm 도 기질',
#  '타 일 압착 붙이다 바탕 12 mm 압 6 mm 도 기질',
#  '타',
#  '타 일',
#  '타 일 압착',
#  '타 일 압착 붙이다',
#  '타 일 압착 붙이다',
#  '타 일 압착 붙이다 바탕',
#  '타 일 압착 붙이다 바탕 68',
#  '타 일 압착 붙이다 바탕 68 mm',
#  '타 일 압착 붙이다 바탕 68 mm',
#  '타 일 압착 붙이다 바탕 68 mm 압',
#  '타 일 압착 붙이다 바탕 68 mm 압 5',
#  '타 일 압착 붙이다 바탕 68 mm 압 5 mm',
#  '타 일 압착 붙이다 바탕 68 mm 압 5 mm',
#  '타 일 압착 붙이다 바탕 68 mm 압 5 mm',
#  '타 일 압착 붙이다 바탕 68 mm 압 5 mm 자다',
#  '타 일 압착 붙이다 바탕 68 mm 압 5 mm 자다',
#  '타',
#  '타 일',
#  '타 일 압착',
#  '타 일 압착 붙이다',
#  '타 일 압착 붙이다',
#  '타 일 압착 붙이다 바탕',
#  '타 일 압착 붙이다 바탕 40',
#  '타 일 압착 붙이다 바탕 40 mm',
#  '타 일 압착 붙이다 바탕 40 mm',
#  '타 일 압착 붙이다 바탕 40 mm 압',
#  '타 일 압착 붙이다 바탕 40 mm 압 5',
#  '타 일 압착 붙이다 바탕 40 mm 압 5 mm',
#  '타 일 압착 붙이다 바탕 40 mm 압 5 mm',
#  '타 일 압착 붙이다 바탕 40 mm 압 5 mm',
#  '타 일 압착 붙이다 바탕 40 mm 압 5 mm 포슬린',
#  '타 일 압착 붙이다 바탕 40 mm 압 5 mm 포슬린',
#  '화강석',
#  '화강석 재료',
#  '화강석 재료 분리',
#  '화강석 재료 분리 대',
#  '화강석 재료 분리 대',
#  '화강석 재료 분리 대 습',
#  '화강석 재료 분리 대 습 식',
#  '화강석 재료 분리 대 습 식',
#  '화강석 재료 분리 대 습 식 물',
#  '화강석 재료 분리 대 습 식 물 갈기',
#  '화강석 재료 분리 대 습 식 물 갈기',
#  '화강석',
#  '화강석 붙이다',
#  '화강석 붙이다',
#  '화강석 붙이다 습',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식 물',
#  '화강석 붙이다 습 식 물 갈기',
#  '화강석 붙이다 습 식 물 갈기',
#  '화강석',
#  '화강석 두',
#  '화강석 두 겁돌',
#  '화강석 두 겁돌',
#  '화강석 두 겁돌 습',
#  '화강석 두 겁돌 습 식',
#  '화강석 두 겁돌 습 식',
#  '화강석 두 겁돌 습 식 버너',
#  '화강석 두 겁돌 습 식 버너',
#  '화강석',
#  '화강석 붙이다',
#  '화강석 붙이다',
#  '화강석 붙이다 습',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식 물',
#  '화강석 붙이다 습 식 물 갈기',
#  '화강석 붙이다 습 식 물 갈기',
#  '화강석',
#  '화강석 붙이다',
#  '화강석 붙이다',
#  '화강석 붙이다 습',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식 버너',
#  '화강석 붙이다 습 식 버너',
#  '화강석 붙이다 습 식 버너',
#  '화강석 붙이다 습 식 버너 주',
#  '화강석 붙이다 습 식 버너 주 자재',
#  '화강석 붙이다 습 식 버너 주 자재 관',
#  '화강석 붙이다 습 식 버너 주 자재 관 급',
#  '화강석 붙이다 습 식 버너 주 자재 관 급 별도',
#  '화강석 붙이다 습 식 버너 주 자재 관 급 별도',
#  '화강석',
#  '화강석 붙이다',
#  '화강석 붙이다',
#  '화강석 붙이다 건',
#  '화강석 붙이다 건 식',
#  '화강석 붙이다 건 식',
#  '화강석 붙이다 건 식 앵커',
#  '화강석 붙이다 건 식 앵커',
#  '화강석 붙이다 건 식 앵커 버너',
#  '화강석 붙이다 건 식 앵커 버너',
#  '화강석 붙이다 건 식 앵커 버너',
#  '화강석 붙이다 건 식 앵커 버너 주',
#  '화강석 붙이다 건 식 앵커 버너 주 자재',
#  '화강석 붙이다 건 식 앵커 버너 주 자재 관',
#  '화강석 붙이다 건 식 앵커 버너 주 자재 관 급',
#  '화강석 붙이다 건 식 앵커 버너 주 자재 관 급 별도',
#  '화강석 붙이다 건 식 앵커 버너 주 자재 관 급 별도',
#  '화강석',
#  '화강석 붙이다',
#  '화강석 붙이다',
#  '화강석 붙이다 습',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식',
#  '화강석 붙이다 습 식 잔',
#  '화강석 붙이다 습 식 잔 다듬다',
#  '화강석 붙이다 습 식 잔 다듬다',
#  '스틸',
#  '스틸 점검',
#  '스틸 점검 구',
#  '스틸 점검 구 뚜껑',
#  '스테인리스',
#  '스테인리스 사다리',
#  '세라믹',
#  '세라믹 논',
#  '세라믹 논 슬립',
#  '세라믹 논 슬립 설치',
#  '스테인리스',
#  '스테인리스 재료',
#  '스테인리스 재료 분리',
#  '스테인리스 재료 분리 대',
#  'AL',
#  'AL 몰딩',
#  'AL 몰딩 설치',
#  'AL 몰딩 설치',
#  'AL 몰딩 설치 W',
#  'AL 몰딩 설치 W 형',
#  'AL 몰딩 설치 W 형',
#  'AL',
#  'AL 몰딩',
#  'AL 몰딩 설치',
#  'AL 몰딩 설치',
#  'AL 몰딩 설치 ㄷ',
#  'AL 몰딩 설치 ㄷ 형',
#  'AL 몰딩 설치 ㄷ 형',
#  '베이스',
#  '베이스 비드',
#  '베이스 비드',
#  '베이스 비드 홈',
#  '베이스 비드 홈 내기',
#  '베이스 비드 홈 내기',
#  '베이스 비드 홈 내기 설치',
#  '철재',
#  '철재 커텐',
#  '철재 커텐 박스',
#  '철재 커텐 박스',
#  '철재 커텐 박스 ㄱ',
#  '철재 커텐 박스 ㄱ 자형',
#  '철재 커텐 박스 ㄱ 자형',
#  '철재',
#  '철재 커텐',
#  '철재 커텐 박스',
#  '철재 커텐 박스',
#  '철재 커텐 박스 ㄱ',
#  '철재 커텐 박스 ㄱ 자형',
#  '철재 커텐 박스 ㄱ 자형',
#  '계단',
#  '계단 실',
#  '계단 실 안전',
#  '계단 실 안전 난간',
#  '스테인리스',
#  '스테인리스 핸드',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일 계단',
#  '스테인리스 핸드 레일 계단 실',
#  '스테인리스 핸드 레일 계단 실',
#  '스테인리스',
#  '스테인리스 핸드',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일 벽',
#  '스테인리스 핸드 레일 벽 부형',
#  '스테인리스 핸드 레일 벽 부형',
#  '스테인리스 핸드 레일 벽 부형 계단',
#  '스테인리스 핸드 레일 벽 부형 계단 실',
#  '스테인리스 핸드 레일 벽 부형 계단 실',
#  '스테인리스',
#  '스테인리스 핸드',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일 벽',
#  '스테인리스 핸드 레일 벽 부형',
#  '스테인리스 핸드 레일 벽 부형',
#  '스테인리스 핸드 레일 벽 부형 복도',
#  '스테인리스 핸드 레일 벽 부형 복도 홀',
#  '스테인리스 핸드 레일 벽 부형 복도 홀',
#  '스테인리스',
#  '스테인리스 핸드',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일',
#  '스테인리스 핸드 레일 옥상',
#  '스테인리스 핸드 레일 옥상 난간',
#  '스테인리스 핸드 레일 옥상 난간',
#  '스틸',
#  '스틸 핸드',
#  '스틸 핸드 레일',
#  '스틸 핸드 레일',
#  '스틸 핸드 레일 테라스',
#  '스틸 핸드 레일 테라스 난간',
#  '스틸 핸드 레일 테라스 난간',
#  '스틸 핸드 레일 테라스 난간 투시',
#  '스틸 핸드 레일 테라스 난간 투시 형',
#  '스틸 핸드 레일 테라스 난간 투시 형',
#  '후',
#  '후 레싱',
#  '후 레싱 스테인리스',
#  '후 레싱 스테인리스',
#  '후 레싱 스테인리스 다',
#  '후 레싱 스테인리스 다 목적',
#  '후 레싱 스테인리스 다 목적 실',
#  '후 레싱 스테인리스 다 목적 실 지붕',
#  '후 레싱 스테인리스 다 목적 실 지붕',
#  '후',
#  '후 레싱',
#  '후 레싱 알루미늄',
#  '후 레싱 알루미늄 시트',
#  '후 레싱 알루미늄 시트',
#  '후 레싱 알루미늄 시트 창호',
#  '후 레싱 알루미늄 시트 창호',
#  '두',
#  '두 겁',
#  '두 겁 대',
#  '두 겁 대 알루미늄',
#  '두 겁 대 알루미늄 시트',
#  '두 겁 대 알루미늄 시트',
#  '두 겁 대 알루미늄 시트 파라',
#  '두 겁 대 알루미늄 시트 파라 펫',
#  '두 겁 대 알루미늄 시트 파라 펫',
#  '경량',
#  '경량 천장',
#  '경량 천장 철골틀',
#  '알루미늄',
#  '알루미늄 시트',
#  '알루미늄 시트 패널',
#  '알루미늄',
#  '알루미늄 천',
#  '알루미늄 천 장재',
#  '합성',
#  '합성 목재',
#  '합성 목재 데크',
#  '합성 목재 데크 깔다',
#  '합성 목재 데크 깔다',
#  '합성 목재 데크 깔다 테라스',
#  '합성 목재 데크 깔다 테라스',
#  '오픈',
#  '오픈 트랜',
#  '오픈 트랜 치',
#  '표면',
#  '표면 마무리',
#  '모르타르',
#  '모르타르 바름',
#  '모르타르',
#  '모르타르 바름',
#  '모르타르',
#  '모르타르 바름',
#  '모르타르',
#  '모르타르 바름',
#  '모르타르',
#  '모르타르 바름',
#  '판넬',
#  '판넬 히팅',
#  '판넬 히팅',
#  '판넬 히팅 160',
#  '판넬 히팅 160 mm',
#  '판넬 히팅 160 mm',
#  '방수',
#  '방수 모르타르',
#  '방수 모르타르 바름',
#  '방수 모르타르 바름',
#  '방수 모르타르 바름 바닥',
#  '방수',
#  '방수 모르타르',
#  '방수 모르타르 바름',
#  '방수 모르타르 바름',
#  '방수 모르타르 바름 벽',
#  '와이어',
#  '와이어 메시',
#  '와이어 메시 바닥',
#  '와이어 메시 바닥 깔다',
#  '콘크리트',
#  '콘크리트',
#  '콘크리트 정리',
#  '',
#  '견적',
#  '견적',
#  '견적 AD',
#  '견적 AD',
#  '견적 AD 1',
#  '견적 AD 1',
#  '견적 AD 1 단',
#  '견적 AD 1 단 열',
#  '견적 AD 1 단 열 폴딩',
#  '견적 AD 1 단 열 폴딩 도어',
#  '견적 AD 1 단 열 폴딩 도어',
#  '',
#  '견적',
#  '견적',
#  '견적 AD',
#  '견적 AD',
#  '견적 AD 2',
#  '견적 AD 2',
#  '견적 AD 2 단',
#  '견적 AD 2 단 열',
#  '견적 AD 2 단 열 폴딩',
#  '견적 AD 2 단 열 폴딩 도어',
#  '견적 AD 2 단 열 폴딩 도어',
#  '',
#  '견적',
#  '견적',
#  '견적 SSD',
#  '견적 SSD',
#  '견적 SSD 1',
#  '견적 SSD 1',
#  '견적 SSD 1 단',
#  '견적 SSD 1 단 열',
#  '견적 SSD 1 단 열 스텐레스',
#  '견적 SSD 1 단 열 스텐레스 프레임',
#  '견적 SSD 1 단 열 스텐레스 프레임',
#  '',
#  '견적',
#  '견적',
#  '견적 SSD',
#  '견적 SSD',
#  '견적 SSD 2',
#  '견적 SSD 2',
#  '견적 SSD 2 단',
#  '견적 SSD 2 단 열',
#  '견적 SSD 2 단 열 스텐레스',
#  '견적 SSD 2 단 열 스텐레스 프레임',
#  '견적 SSD 2 단 열 스텐레스 프레임',
#  '',
#  '견적',
#  '견적',
#  '견적 SSD',
#  '견적 SSD',
#  '견적 SSD 3',
#  '견적 SSD 3',
#  '견적 SSD 3 단',
#  '견적 SSD 3 단 열',
#  '견적 SSD 3 단 열 스텐레스',
#  '견적 SSD 3 단 열 스텐레스 프레임',
#  '견적 SSD 3 단 열 스텐레스 프레임',
#  '',
#  '견적',
#  '견적',
#  '견적 SSD',
#  '견적 SSD',
#  '견적 SSD 4',
#  '',
#  '견적',
#  '견적',
#  '견적 SSD',
#  '견적 SSD',
#  '견적 SSD 5',
#  '',
#  '견적',
#  '견적',
#  '견적 SSD',
#  '견적 SSD',
#  '견적 SSD 6',
#  '',
#  '견적',
#  '견적',
#  '견적 SD',
#  '견적 SD',
#  '견적 SD 1',
#  '견적 SD 1',
#  '견적 SD 1 단',
#  '견적 SD 1 단 열',
#  '견적 SD 1 단 열 방화',
#  '견적 SD 1 단 열 방화 문',
#  '견적 SD 1 단 열 방화 문',
#  '',
#  '견적',
#  '견적',
#  '견적 SD',
#  '견적 SD',
#  '견적 SD 2',
#  '',
#  '견적',
#  '견적',
#  '견적 SD',
#  '견적 SD',
#  '견적 SD 3',
#  '',
#  '견적',
#  '견적',
#  '견적 SD',
#  '견적 SD',
#  '견적 SD 4',
#  '',
#  '견적',
#  '견적',
#  '견적 SD',
#  '견적 SD',
#  '견적 SD 5',
#  '',
#  '견적',
#  '견적',
#  '견적 PD',
#  '견적 PD',
#  '견적 PD 1',
#  '',
#  '견적',
#  '견적',
#  '견적 PD',
#  '견적 PD',
#  '견적 PD 2',
#  '',
#  '견적',
#  '견적',
#  '견적 PD',
#  '견적 PD',
#  '견적 PD 3',
#  '',
#  '견적',
#  '견적',
#  '견적 세이프',
#  '견적 세이프 강화도',
#  '견적 세이프 강화도 어',
#  '견적 세이프 강화도 어',
#  '견적 세이프 강화도 어 단열',
#  '견적 세이프 강화도 어 단열',
#  '',
#  '견적',
#  '견적',
#  '견적 세이프',
#  '견적 세이프 강화도',
#  '견적 세이프 강화도 어',
#  '견적 세이프 강화도 어',
#  '견적 세이프 강화도 어 단열',
#  '견적 세이프 강화도 어 단열',
#  '',
#  '견적',
#  '견적',
#  '견적 세이프',
#  '견적 세이프 강화도',
#  '견적 세이프 강화도 어',
#  'SSD',
#  'SSD 부자',
#  'SSD 부자 재',
#  'SSD 부자 재',
#  'SSD 부자 재 견적',
#  'SSD 부자 재 견적 밉다',
#  'SSD 부자 재 견적 밉다 포함',
#  'SSD 부자 재 견적 밉다 포함 항목',
#  'SSD 부자 재 견적 밉다 포함 항목',
#  'SD',
#  'SD 부자',
#  'SD 부자 재',
#  'SD 부자 재',
#  'SD 부자 재 견적',
#  'SD 부자 재 견적 밉다',
#  'SD 부자 재 견적 밉다 포함',
#  'SD 부자 재 견적 밉다 포함 항목',
#  'SD 부자 재 견적 밉다 포함 항목',
#  'PD',
#  'PD 부자',
#  'PD 부자 재',
#  'PD 부자 재',
#  'PD 부자 재 견적',
#  'PD 부자 재 견적 밉다',
#  'PD 부자 재 견적 밉다 포함',
#  'PD 부자 재 견적 밉다 포함 항목',
#  'PD 부자 재 견적 밉다 포함 항목',
#  'PW',
#  'PW',
#  'PW 01',
#  'PW 01',
#  'PW 01 250',
#  'PW 01 250 mm',
#  'PW 01 250 mm',
#  'PW',
#  'PW',
#  'PW 02',
#  'PW 02',
#  'PW 02 250',
#  'PW 02 250 mm',
#  'PW 02 250 mm',
#  'PW',
#  'PW',
#  'PW 03',
#  'PW 03',
#  'PW 03 250',
#  'PW 03 250 mm',
#  'PW 03 250 mm',
#  '창문',
#  '창문 틀',
#  '창문 틀 주위',
#  '창문 틀 주위 충전',
#  '창문',
#  '창문 틀',
#  '창문 틀 주위',
#  '창문 틀 주위 충전',
#  '수',
#  '수 밀코킹',
#  '수 밀코킹',
#  '수 밀코킹 실리콘',
#  '수 밀코킹 실리콘',
#  '강화유리',
#  '강화유리',
#  '강화유리 투명',
#  '강화유리 투명',
#  '강화유리 투명 5',
#  '강화유리 투명 5 mm',
#  '투명',
#  '투명 복층',
#  '투명 복층 유리',
#  '투명 복층 유리',
#  '투명 복층 유리 24',
#  '투명 복층 유리 24 mm',
#  '투명 복층 유리 24 mm',
#  '투명 복층 유리 24 mm 6',
#  '투명 복층 유리 24 mm 6 CL',
#  '투명 복층 유리 24 mm 6 CL',
#  '투명 복층 유리 24 mm 6 CL 12',
#  '투명 복층 유리 24 mm 6 CL 12 R',
#  '투명 복층 유리 24 mm 6 CL 12 R',
#  '투명 복층 유리 24 mm 6 CL 12 R 6',
#  '투명 복층 유리 24 mm 6 CL 12 R 6 LE',
#  '투명 복층 유리 24 mm 6 CL 12 R 6 LE',
#  '로이',
#  '로이 복층',
#  '로이 복층 유리',
#  '로이 복층 유리',
#  '로이 복층 유리 28',
#  '로이 복층 유리 28 mm',
#  '로이 복층 유리 28 mm',
#  '로이 복층 유리 28 mm 6',
#  '로이 복층 유리 28 mm 6 LE',
#  '로이 복층 유리 28 mm 6 LE',
#  '로이 복층 유리 28 mm 6 LE 16',
#  '로이 복층 유리 28 mm 6 LE 16 AR',
#  '로이 복층 유리 28 mm 6 LE 16 AR',
#  '로이 복층 유리 28 mm 6 LE 16 AR 6',
#  '로이 복층 유리 28 mm 6 LE 16 AR 6 LE',
#  '로이 복층 유리 28 mm 6 LE 16 AR 6 LE',
#  '투명',
#  '투명 삼중',
#  '투명 삼중 유리',
#  '투명 삼중 유리',
#  '투명 삼중 유리 39',
#  '투명 삼중 유리 39 mm',
#  '투명 삼중 유리 39 mm',
#  '투명 삼중 유리 39 mm 5',
#  '투명 삼중 유리 39 mm 5 LE',
#  '투명 삼중 유리 39 mm 5 LE',
#  '투명 삼중 유리 39 mm 5 LE 12',
#  '투명 삼중 유리 39 mm 5 LE 12 AR',
#  '투명 삼중 유리 39 mm 5 LE 12 AR',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0 12',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0 12 AR',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0 12 AR',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0 12 AR 5',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0 12 AR 5 LE',
#  '투명 삼중 유리 39 mm 5 LE 12 AR 5 C 0 12 AR 5 LE',
#  '투명',
#  '투명 삼중',
#  '투명 삼중 유리',
#  '투명 삼중 유리',
#  '투명 삼중 유리 42',
#  '투명 삼중 유리 42 mm',
#  '투명 삼중 유리 42 mm',
#  '투명 삼중 유리 42 mm 6',
#  '투명 삼중 유리 42 mm 6 LE',
#  '투명 삼중 유리 42 mm 6 LE',
#  '투명 삼중 유리 42 mm 6 LE 12',
#  '투명 삼중 유리 42 mm 6 LE 12 AR',
#  '투명 삼중 유리 42 mm 6 LE 12 AR',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL 12',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL 12 AR',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL 12 AR',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL 12 AR 6',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL 12 AR 6 LE',
#  '투명 삼중 유리 42 mm 6 LE 12 AR 6 CL 12 AR 6 LE',
#  '유리',
#  '유리 주위',
#  '유리 주위 코킹',
#  '바탕',
#  '바탕 만들기',
#  '바탕 만들기',
#  '바탕 만들기 걸레받이',
#  '바탕 만들기 걸레받이 용',
#  '바탕 만들기 걸레받이 용 페인트',
#  '무늬',
#  '무늬 코트',
#  '수성',
#  '수성 페인트',
#  '수성 페인트',
#  '수성 페인트 롤러',
#  '수성 페인트 롤러 칠',
#  '수성 페인트 롤러 칠',
#  '수성',
#  '수성 페인트',
#  '수성 페인트',
#  '수성 페인트 롤러',
#  '수성 페인트 롤러 칠',
#  '수성 페인트 롤러 칠',
#  '비닐',
#  '비닐 타일',
#  '비닐 타일 깔다',
#  '악세다',
#  '악세다 스후',
#  '악세다 스후',
#  '악세다 스후',
#  '악세다 스후',
#  '악세다 스후 전도성',
#  '악세다 스후 전도성 타',
#  '악세다 스후 전도성 타 일',
#  '악세다 스후 전도성 타 일 마감',
#  '악세다 스후 전도성 타 일 마감',
#  '타일',
#  '타일 카펫',
#  '타일 카펫 깔다',
#  '발포',
#  '발포 폴리스티렌',
#  '발포 폴리스티렌',
#  '발포 폴리스티렌 슬래브',
#  '발포 폴리스티렌 슬래브 위',
#  '발포 폴리스티렌 슬래브 위 깔다',
#  '발포 폴리스티렌 슬래브 위 깔다',
#  '발포 폴리스티렌 슬래브 위 깔다 바닥',
#  '발포 폴리스티렌 슬래브 위 깔다 바닥',
#  '발포',
#  '발포 폴리스티렌',
#  '발포 폴리스티렌',
#  '발포 폴리스티렌 콘크리트',
#  '발포 폴리스티렌 콘크리트 타',
#  '발포 폴리스티렌 콘크리트 타 설',
#  '발포 폴리스티렌 콘크리트 타 설 부착',
#  '발포 폴리스티렌 콘크리트 타 설 부착',
#  '발포 폴리스티렌 콘크리트 타 설 부착 바닥',
#  '발포 폴리스티렌 콘크리트 타 설 부착 바닥',
#  '열경화성수지',
#  '열경화성수지 천',
#  '열경화성수지 천 장재',
#  '로이',
#  '로이',
#  '로이 Low',
#  '로이 Low',
#  '로이 Low E',
#  '로이 Low E',
#  '로이 Low E 단',
#  '로이 Low E 단 열',
#  '로이 Low E 단 열 재',
#  '로이 Low E 단 열 재 설치',
#  '로이 Low E 단 열 재 설치',
#  '로이 Low E 단 열 재 설치 100',
#  '로이 Low E 단 열 재 설치 100 mm',
#  '로이 Low E 단 열 재 설치 100 mm',
#  '로이 Low E 단 열 재 설치 100 mm 준불연',
#  '로이 Low E 단 열 재 설치 100 mm 준불연',
#  '로이 Low E 단 열 재 설치 100 mm 준불연',
#  '로이 Low E 단 열 재 설치 100 mm 준불연 주',
#  '로이 Low E 단 열 재 설치 100 mm 준불연 주 자재',
#  '로이 Low E 단 열 재 설치 100 mm 준불연 주 자재 관',
#  ...]

# %%
model.most_similar(positive=['운반비'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-f2495a0de500> in <module>
# ----> 1 model.most_similar(positive=['운반비'])
#
# ~\Anaconda3\envs\ken\lib\site-packages\gensim\utils.py in new_func1(*args, **kwargs)
#    1396                     stacklevel=2
#    1397                 )
# -> 1398                 return func(*args, **kwargs)
#    1399
#    1400             return new_func1
#
# ~\Anaconda3\envs\ken\lib\site-packages\gensim\models\base_any2vec.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     694         Refer to the documentation for `gensim.models.keyedvectors.WordEmbeddingsKeyedVectors.most_similar`
#     695         """
# --> 696         return self.wv.most_similar(positive, negative, topn, restrict_vocab, indexer)
#     697
#     698     @deprecated("Method will be removed in 4.0.0, use self.wv.wmdistance() instead")
#
# ~\Anaconda3\envs\ken\lib\site-packages\gensim\models\keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     363                 mean.append(weight * word)
#     364             else:
# --> 365                 mean.append(weight * self.word_vec(word, use_norm=True))
#     366                 if word in self.vocab:
#     367                     all_words.add(self.vocab[word].index)
#
# ~\Anaconda3\envs\ken\lib\site-packages\gensim\models\keyedvectors.py in word_vec(self, word, use_norm)
#     272             return result
#     273         else:
# --> 274             raise KeyError("word '%s' not in vocabulary" % word)
#     275
#     276     def get_vector(self, word):
#
# KeyError: "word '운반비' not in vocabulary"
